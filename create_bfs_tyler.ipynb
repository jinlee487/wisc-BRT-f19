# %%
import pickle, copy
import pandas as pd
pd.set_option('max_colwidth', 200)
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.colors as pltc
import seaborn as sns 
sns.set()
import os
from os import listdir
from os.path import isfile, join
import csv
import numpy as np
# %matplotlib inline
from random import sample
from math import sin, cos, sqrt, atan2, radians, acos
import numpy as np
import math
import copy
import time
from datetime import datetime, timedelta

# %%
def save_obj(obj, name ):
    with open('obj/'+ name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj(name ):
    with open('obj/' + name + '.pkl', 'rb') as f:
        return pickle.load(f)

# %%
g = load_obj('graph_final_fixed')

# %%
g
# Out:
# {'1379_25260': [{'destination': '1717_25301',
#    'travel_time': 41,
#    'trip_id': 884545,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TFR PT'}],
#  '1717_25301': [{'destination': '1923_26296',
#    'travel_time': 995,
#    'trip_id': 884531,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TFR PT'},
#   {'destination': '1923_25352',
#    'travel_time': 51,
#    'trip_id': 884545,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TFR PT'},
#   {'destination': '1923_26236',
#    'travel_time': 935,
#    'trip_id': 904832,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TRANSFER'}],
#  '1923_25352': [{'destination': '1715_26333',
#    'travel_time': 981,
#    'trip_id': 884531,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TFR PT'},
#   {'destination': '1715_25399',
#    'travel_time': 47,
#    'trip_id': 884545,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TFR PT'},
#   {'destination': '1715_26273',
#    'travel_time': 921,
#    'trip_id': 904832,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TRANSFER'}],
#  '1715_25399': [{'destination': '1561_26363',
#    'travel_time': 964,
#    'trip_id': 884531,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TFR PT'},
#   {'destination': '1561_25438',
#    'travel_time': 39,
#    'trip_id': 884545,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TFR PT'},
#   {'destination': '1561_26303',
#    'travel_time': 904,
#    'trip_id': 904832,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TRANSFER'}],
#  '1561_25438': [{'destination': '1877_26399',
#    'travel_time': 961,
#    'trip_id': 884531,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TFR PT'},
#   {'destination': '1877_25483',
#    'travel_time': 45,
#    'trip_id': 884545,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TFR PT'},
#   {'destination': '1877_26339',
#    'travel_time': 901,
#    'trip_id': 904832,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TRANSFER'},
#   {'destination': '1341_27056',
#    'travel_time': 1618,
#    'trip_id': 889499,
#    'bus_name': 22,
#    'full_bus_name': '22_NORTH TFR PT: VIA MENDOTA'},
#   {'destination': '1341_26216',
#    'travel_time': 778,
#    'trip_id': 889500,
#    'bus_name': 22,
#    'full_bus_name': '22_NORTH TFR PT: VIA MENDOTA'},
#   {'destination': '1341_26216',
#    'travel_time': 778,
#    'trip_id': 899625,
#    'bus_name': 22,
#    'full_bus_name': '22_NORTH TRANSFER: VIA MENDOTA'},
#   {'destination': '1341_27056',
#    'travel_time': 1618,
#    'trip_id': 899626,
#    'bus_name': 22,
#    'full_bus_name': '22_NORTH TRANSFER: VIA MENDOTA'}],
#  '1877_25483': [{'destination': '1759_26420',
#    'travel_time': 937,
#    'trip_id': 884531,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TFR PT'},
#   {'destination': '1759_25510',
#    'travel_time': 27,
#    'trip_id': 884545,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TFR PT'},
#   {'destination': '1759_26360',
#    'travel_time': 877,
#    'trip_id': 904832,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TRANSFER'},
#   {'destination': '1759_26576',
#    'travel_time': 1093,
#    'trip_id': 889501,
#    'bus_name': 22,
#    'full_bus_name': '22_NORTH TFR PT'},
#   {'destination': '1759_25736',
#    'travel_time': 253,
#    'trip_id': 889502,
#    'bus_name': 22,
#    'full_bus_name': '22_NORTH TFR PT'},
#   {'destination': '1759_25736',
#    'travel_time': 253,
#    'trip_id': 899623,
#    'bus_name': 22,
#    'full_bus_name': '22_NORTH TRANSFER'},
#   {'destination': '1759_26576',
#    'travel_time': 1093,
#    'trip_id': 899624,
#    'bus_name': 22,
#    'full_bus_name': '22_NORTH TRANSFER'}],
#  '1759_25510': [{'destination': '5100_26460',
#    'travel_time': 950,
#    'trip_id': 884531,
#    'bus_name': 2,
#    'full_bus_name': '2_DROP OFFS ONLY'},
#   {'destination': '5100_25560',
#    'travel_time': 50,
#    'trip_id': 884545,
#    'bus_name': 2,
#    'full_bus_name': '2_DROP OFFS ONLY'},
#   {'destination': '5100_26400',
#    'travel_time': 890,
#    'trip_id': 904832,
#    'bus_name': 2,
#    'full_bus_name': '2_DROP OFFS ONLY'},
#   {'destination': '5100_26640',
#    'travel_time': 1130,
#    'trip_id': 889501,
#    'bus_name': 22,
#    'full_bus_name': '22_DROP OFFS ONLY'},
#   {'destination': '5100_25800',
#    'travel_time': 290,
#    'trip_id': 889502,
#    'bus_name': 22,
#    'full_bus_name': '22_DROP OFFS ONLY'},
#   {'destination': '5100_25800',
#    'travel_time': 290,
#    'trip_id': 899623,
#    'bus_name': 22,
#    'full_bus_name': '22_DROP OFFS ONLY'},
#   {'destination': '5100_26640',
#    'travel_time': 1130,
#    'trip_id': 899624,
#    'bus_name': 22,
#    'full_bus_name': '22_DROP OFFS ONLY'}],
#  '5100_25560': [{'destination': '1504_27070',
#    'travel_time': 1510,
#    'trip_id': 884579,
#    'bus_name': 2,
#    'full_bus_name': '2_WEST TFR PT: VIA SHERMAN'},
#   {'destination': '1504_27070',
#    'travel_time': 1510,
#    'trip_id': 904880,
#    'bus_name': 2,
#    'full_bus_name': '2_WEST TRANSFER: VIA SHERMAN'},
#   {'destination': '1895_27065',
#    'travel_time': 1505,
#    'trip_id': 885288,
#    'bus_name': 4,
#    'full_bus_name': '4_SOUTH TFR PT'},
#   {'destination': '1895_27065',
#    'travel_time': 1505,
#    'trip_id': 895428,
#    'bus_name': 4,
#    'full_bus_name': '4_SOUTH TRANSFER'},
#   {'destination': '1895_27042',
#    'travel_time': 1482,
#    'trip_id': 887942,
#    'bus_name': 17,
#    'full_bus_name': '17_EAST TFR PT'},
#   {'destination': '1895_27042',
#    'travel_time': 1482,
#    'trip_id': 898063,
#    'bus_name': 17,
#    'full_bus_name': '17_EAST TRANSFER'},
#   {'destination': '1895_27028',
#    'travel_time': 1468,
#    'trip_id': 888906,
#    'bus_name': 20,
#    'full_bus_name': '20_E TOWNE: VIA AIRPORT'},
#   {'destination': '1895_27028',
#    'travel_time': 1468,
#    'trip_id': 899057,
#    'bus_name': 20,
#    'full_bus_name': '20_E TOWNE: VIA AIRPORT'},
#   {'destination': '1895_27027',
#    'travel_time': 1467,
#    'trip_id': 889299,
#    'bus_name': 21,
#    'full_bus_name': '21_NORTH TFR PT: VIA LAKEVIEW'},
#   {'destination': '1895_26127',
#    'travel_time': 567,
#    'trip_id': 889300,
#    'bus_name': 21,
#    'full_bus_name': '21_NORTH TFR PT: VIA LAKEVIEW'},
#   {'destination': '1895_26127',
#    'travel_time': 567,
#    'trip_id': 899475,
#    'bus_name': 21,
#    'full_bus_name': '21_NORTH TRANSFER: VIA LAKEVIEW'},
#   {'destination': '1895_27027',
#    'travel_time': 1467,
#    'trip_id': 899476,
#    'bus_name': 21,
#    'full_bus_name': '21_NORTH TRANSFER: VIA LAKEVIEW'},
#   {'destination': '1410_27002',
#    'travel_time': 1442,
#    'trip_id': 889499,
#    'bus_name': 22,
#    'full_bus_name': '22_NORTH TFR PT: VIA MENDOTA'},
#   {'destination': '1410_26162',
#    'travel_time': 602,
#    'trip_id': 889500,
#    'bus_name': 22,
#    'full_bus_name': '22_NORTH TFR PT: VIA MENDOTA'},
#   {'destination': '1410_26162',
#    'travel_time': 602,
#    'trip_id': 899625,
#    'bus_name': 22,
#    'full_bus_name': '22_NORTH TRANSFER: VIA MENDOTA'},
#   {'destination': '1410_27002',
#    'travel_time': 1442,
#    'trip_id': 899626,
#    'bus_name': 22,
#    'full_bus_name': '22_NORTH TRANSFER: VIA MENDOTA'},
#   {'destination': '1895_26160',
#    'travel_time': 600,
#    'trip_id': 889883,
#    'bus_name': 27,
#    'full_bus_name': '27_UW CAMPUS: VIA WASHINGTON AV'},
#   {'destination': '1895_26160',
#    'travel_time': 600,
#    'trip_id': 904797,
#    'bus_name': 27,
#    'full_bus_name': '27_U.W. CAMPUS: VIA WASHINGTON'},
#   {'destination': '1504_25872',
#    'travel_time': 312,
#    'trip_id': 889933,
#    'bus_name': 28,
#    'full_bus_name': '28_WEST TFR PT'},
#   {'destination': '1504_26186',
#    'travel_time': 626,
#    'trip_id': 889941,
#    'bus_name': 28,
#    'full_bus_name': '28_TO UW HOSPITAL'},
#   {'destination': '1504_27026',
#    'travel_time': 1466,
#    'trip_id': 889944,
#    'bus_name': 28,
#    'full_bus_name': '28_TO UW HOSPITAL'},
#   {'destination': '1504_27026',
#    'travel_time': 1466,
#    'trip_id': 900078,
#    'bus_name': 28,
#    'full_bus_name': '28_TO U.W. HOSPITAL'},
#   {'destination': '1504_26186',
#    'travel_time': 626,
#    'trip_id': 900081,
#    'bus_name': 28,
#    'full_bus_name': '28_TO U.W. HOSPITAL'},
#   {'destination': '1504_25872',
#    'travel_time': 312,
#    'trip_id': 900089,
#    'bus_name': 28,
#    'full_bus_name': '28_WEST TRANSFER'}],
#  '435_25204': [{'destination': '941_25239',
#    'travel_time': 35,
#    'trip_id': 884531,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TFR PT: VIA SHERMAN'},
#   {'destination': '941_26139',
#    'travel_time': 935,
#    'trip_id': 884544,
#    'bus_name': 2,
#    'full_bus_name': '2_CAPITOL SQUARE'},
#   {'destination': '941_27039',
#    'travel_time': 1835,
#    'trip_id': 884556,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TFR PT: VIA FORDEM'},
#   {'destination': '941_26131',
#    'travel_time': 927,
#    'trip_id': 904845,
#    'bus_name': 2,
#    'full_bus_name': '2_CAPITOL SQUARE'},
#   {'destination': '941_25813',
#    'travel_time': 609,
#    'trip_id': 885035,
#    'bus_name': 3,
#    'full_bus_name': '3_EAST TFR PT: VIA DIVISION'},
#   {'destination': '941_25685',
#    'travel_time': 481,
#    'trip_id': 895174,
#    'bus_name': 3,
#    'full_bus_name': '3_EAST TRANSFER: VIA DIVISION'},
#   {'destination': '941_26760',
#    'travel_time': 1556,
#    'trip_id': 886636,
#    'bus_name': 10,
#    'full_bus_name': '10_TO WILSON ST'},
#   {'destination': '941_26760',
#    'travel_time': 1556,
#    'trip_id': 896783,
#    'bus_name': 10,
#    'full_bus_name': '10_TO WILSON'},
#   {'destination': '941_26157',
#    'travel_time': 953,
#    'trip_id': 886969,
#    'bus_name': 11,
#    'full_bus_name': '11_DUTCH MILL'},
#   {'destination': '941_26220',
#    'travel_time': 1016,
#    'trip_id': 897120,
#    'bus_name': 11,
#    'full_bus_name': '11_DUTCH MILL'},
#   {'destination': '941_26328',
#    'travel_time': 1124,
#    'trip_id': 887308,
#    'bus_name': 14,
#    'full_bus_name': '14_EAST TFR PT'},
#   {'destination': '941_26328',
#    'travel_time': 1124,
#    'trip_id': 897473,
#    'bus_name': 14,
#    'full_bus_name': '14_EAST TRANSFER'},
#   {'destination': '941_25702',
#    'travel_time': 498,
#    'trip_id': 887461,
#    'bus_name': 15,
#    'full_bus_name': '15_EAST TFR PT'},
#   {'destination': '941_25702',
#    'travel_time': 498,
#    'trip_id': 897605,
#    'bus_name': 15,
#    'full_bus_name': '15_EAST TRANSFER'},
#   {'destination': '941_25251',
#    'travel_time': 47,
#    'trip_id': 888795,
#    'bus_name': 19,
#    'full_bus_name': '19_CAPITOL SQUARE'},
#   {'destination': '941_25251',
#    'travel_time': 47,
#    'trip_id': 898923,
#    'bus_name': 19,
#    'full_bus_name': '19_CAPITOL SQUARE'},
#   {'destination': '941_26581',
#    'travel_time': 1377,
#    'trip_id': 889877,
#    'bus_name': 27,
#    'full_bus_name': '27_NORTH TFR PT: VIA JOHNSON'},
#   {'destination': '941_26581',
#    'travel_time': 1377,
#    'trip_id': 904791,
#    'bus_name': 27,
#    'full_bus_name': '27_NORTH TRANSFER: VIA JOHNSON'},
#   {'destination': '941_26760',
#    'travel_time': 1556,
#    'trip_id': 891012,
#    'bus_name': 37,
#    'full_bus_name': '37_PFLAUM RD'},
#   {'destination': '941_26700',
#    'travel_time': 1496,
#    'trip_id': 901140,
#    'bus_name': 37,
#    'full_bus_name': '37_PFLAUM'},
#   {'destination': '941_26302',
#    'travel_time': 1098,
#    'trip_id': 891419,
#    'bus_name': 47,
#    'full_bus_name': '47_CAPITOL SQUARE: VIA PARK'},
#   {'destination': '941_26302',
#    'travel_time': 1098,
#    'trip_id': 901556,
#    'bus_name': 47,
#    'full_bus_name': '47_CAPITOL SQUARE: VIA PARK'},
#   {'destination': '941_25333',
#    'travel_time': 129,
#    'trip_id': 891951,
#    'bus_name': 56,
#    'full_bus_name': '56_NORTH TFR PT'},
#   {'destination': '941_25333',
#    'travel_time': 129,
#    'trip_id': 902104,
#    'bus_name': 56,
#    'full_bus_name': '56_NORTH TRANSFER'},
#   {'destination': '941_26208',
#    'travel_time': 1004,
#    'trip_id': 892019,
#    'bus_name': 57,
#    'full_bus_name': '57_NORTH TFR PT'},
#   {'destination': '941_26208',
#    'travel_time': 1004,
#    'trip_id': 902156,
#    'bus_name': 57,
#    'full_bus_name': '57_NORTH TRANSFER'},
#   {'destination': '941_26713',
#    'travel_time': 1509,
#    'trip_id': 892086,
#    'bus_name': 58,
#    'full_bus_name': '58_CAPITOL SQUARE'},
#   {'destination': '941_26671',
#    'travel_time': 1467,
#    'trip_id': 902226,
#    'bus_name': 58,
#    'full_bus_name': '58_CAPITOL SQUARE'},
#   {'destination': '941_25822',
#    'travel_time': 618,
#    'trip_id': 892771,
#    'bus_name': 71,
#    'full_bus_name': '71_CAPITOL SQUARE'},
#   {'destination': '941_25822',
#    'travel_time': 618,
#    'trip_id': 902908,
#    'bus_name': 71,
#    'full_bus_name': '71_CAPITOL SQUARE'},
#   {'destination': '941_26688',
#    'travel_time': 1484,
#    'trip_id': 892828,
#    'bus_name': 72,
#    'full_bus_name': '72_CAPITOL SQUARE'},
#   {'destination': '941_26688',
#    'travel_time': 1484,
#    'trip_id': 902966,
#    'bus_name': 72,
#    'full_bus_name': '72_CAPITOL SQUARE'}],
#  '941_25239': [{'destination': '839_25349',
#    'travel_time': 110,
#    'trip_id': 884531,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TFR PT: VIA SHERMAN'},
#   {'destination': '839_26249',
#    'travel_time': 1010,
#    'trip_id': 884544,
#    'bus_name': 2,
#    'full_bus_name': '2_CAPITOL SQUARE'},
#   {'destination': '839_27149',
#    'travel_time': 1910,
#    'trip_id': 884556,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TFR PT: VIA FORDEM'},
#   {'destination': '839_26223',
#    'travel_time': 984,
#    'trip_id': 904845,
#    'bus_name': 2,
#    'full_bus_name': '2_CAPITOL SQUARE'},
#   {'destination': '839_25932',
#    'travel_time': 693,
#    'trip_id': 885035,
#    'bus_name': 3,
#    'full_bus_name': '3_EAST TFR PT: VIA DIVISION'},
#   {'destination': '839_25786',
#    'travel_time': 547,
#    'trip_id': 895174,
#    'bus_name': 3,
#    'full_bus_name': '3_EAST TRANSFER: VIA DIVISION'},
#   {'destination': '470_26811',
#    'travel_time': 1572,
#    'trip_id': 886636,
#    'bus_name': 10,
#    'full_bus_name': '10_TO WILSON ST'},
#   {'destination': '470_26811',
#    'travel_time': 1572,
#    'trip_id': 896783,
#    'bus_name': 10,
#    'full_bus_name': '10_TO WILSON'},
#   {'destination': '839_26283',
#    'travel_time': 1044,
#    'trip_id': 886969,
#    'bus_name': 11,
#    'full_bus_name': '11_DUTCH MILL'},
#   {'destination': '470_26254',
#    'travel_time': 1015,
#    'trip_id': 897120,
#    'bus_name': 11,
#    'full_bus_name': '11_DUTCH MILL'},
#   {'destination': '839_26436',
#    'travel_time': 1197,
#    'trip_id': 887308,
#    'bus_name': 14,
#    'full_bus_name': '14_EAST TFR PT'},
#   {'destination': '839_26436',
#    'travel_time': 1197,
#    'trip_id': 897473,
#    'bus_name': 14,
#    'full_bus_name': '14_EAST TRANSFER'},
#   {'destination': '839_25798',
#    'travel_time': 559,
#    'trip_id': 887461,
#    'bus_name': 15,
#    'full_bus_name': '15_EAST TFR PT'},
#   {'destination': '839_25798',
#    'travel_time': 559,
#    'trip_id': 897605,
#    'bus_name': 15,
#    'full_bus_name': '15_EAST TRANSFER'},
#   {'destination': '470_25303',
#    'travel_time': 64,
#    'trip_id': 888795,
#    'bus_name': 19,
#    'full_bus_name': '19_CAPITOL SQUARE'},
#   {'destination': '470_25303',
#    'travel_time': 64,
#    'trip_id': 898923,
#    'bus_name': 19,
#    'full_bus_name': '19_CAPITOL SQUARE'},
#   {'destination': '839_26636',
#    'travel_time': 1397,
#    'trip_id': 889877,
#    'bus_name': 27,
#    'full_bus_name': '27_NORTH TFR PT: VIA JOHNSON'},
#   {'destination': '839_26636',
#    'travel_time': 1397,
#    'trip_id': 904791,
#    'bus_name': 27,
#    'full_bus_name': '27_NORTH TRANSFER: VIA JOHNSON'},
#   {'destination': '839_26864',
#    'travel_time': 1625,
#    'trip_id': 891012,
#    'bus_name': 37,
#    'full_bus_name': '37_PFLAUM RD'},
#   {'destination': '839_26825',
#    'travel_time': 1586,
#    'trip_id': 901140,
#    'bus_name': 37,
#    'full_bus_name': '37_PFLAUM'},
#   {'destination': '839_26397',
#    'travel_time': 1158,
#    'trip_id': 891419,
#    'bus_name': 47,
#    'full_bus_name': '47_CAPITOL SQUARE: VIA PARK'},
#   {'destination': '839_26397',
#    'travel_time': 1158,
#    'trip_id': 901556,
#    'bus_name': 47,
#    'full_bus_name': '47_CAPITOL SQUARE: VIA PARK'},
#   {'destination': '839_25453',
#    'travel_time': 214,
#    'trip_id': 891951,
#    'bus_name': 56,
#    'full_bus_name': '56_NORTH TFR PT'},
#   {'destination': '839_25453',
#    'travel_time': 214,
#    'trip_id': 902104,
#    'bus_name': 56,
#    'full_bus_name': '56_NORTH TRANSFER'},
#   {'destination': '839_26316',
#    'travel_time': 1077,
#    'trip_id': 892019,
#    'bus_name': 57,
#    'full_bus_name': '57_NORTH TFR PT'},
#   {'destination': '839_26316',
#    'travel_time': 1077,
#    'trip_id': 902156,
#    'bus_name': 57,
#    'full_bus_name': '57_NORTH TRANSFER'},
#   {'destination': '839_26832',
#    'travel_time': 1593,
#    'trip_id': 892086,
#    'bus_name': 58,
#    'full_bus_name': '58_CAPITOL SQUARE'},
#   {'destination': '839_26763',
#    'travel_time': 1524,
#    'trip_id': 902226,
#    'bus_name': 58,
#    'full_bus_name': '58_CAPITOL SQUARE'},
#   {'destination': '839_25918',
#    'travel_time': 679,
#    'trip_id': 892771,
#    'bus_name': 71,
#    'full_bus_name': '71_CAPITOL SQUARE'},
#   {'destination': '839_25918',
#    'travel_time': 679,
#    'trip_id': 902908,
#    'bus_name': 71,
#    'full_bus_name': '71_CAPITOL SQUARE'},
#   {'destination': '839_26796',
#    'travel_time': 1557,
#    'trip_id': 892828,
#    'bus_name': 72,
#    'full_bus_name': '72_CAPITOL SQUARE'},
#   {'destination': '839_26796',
#    'travel_time': 1557,
#    'trip_id': 902966,
#    'bus_name': 72,
#    'full_bus_name': '72_CAPITOL SQUARE'}],
#  '839_25349': [{'destination': '883_25435',
#    'travel_time': 86,
#    'trip_id': 884531,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TFR PT: VIA SHERMAN'},
#   {'destination': '883_26335',
#    'travel_time': 986,
#    'trip_id': 884544,
#    'bus_name': 2,
#    'full_bus_name': '2_CAPITOL SQUARE'},
#   {'destination': '883_27235',
#    'travel_time': 1886,
#    'trip_id': 884556,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TFR PT: VIA FORDEM'},
#   {'destination': '883_26294',
#    'travel_time': 945,
#    'trip_id': 904845,
#    'bus_name': 2,
#    'full_bus_name': '2_CAPITOL SQUARE'},
#   {'destination': '883_26025',
#    'travel_time': 676,
#    'trip_id': 885035,
#    'bus_name': 3,
#    'full_bus_name': '3_EAST TFR PT: VIA DIVISION'},
#   {'destination': '883_25865',
#    'travel_time': 516,
#    'trip_id': 895174,
#    'bus_name': 3,
#    'full_bus_name': '3_EAST TRANSFER: VIA DIVISION'},
#   {'destination': '883_26381',
#    'travel_time': 1032,
#    'trip_id': 886969,
#    'bus_name': 11,
#    'full_bus_name': '11_DUTCH MILL'},
#   {'destination': '883_26520',
#    'travel_time': 1171,
#    'trip_id': 887308,
#    'bus_name': 14,
#    'full_bus_name': '14_EAST TFR PT'},
#   {'destination': '883_26520',
#    'travel_time': 1171,
#    'trip_id': 897473,
#    'bus_name': 14,
#    'full_bus_name': '14_EAST TRANSFER'},
#   {'destination': '883_25873',
#    'travel_time': 524,
#    'trip_id': 887461,
#    'bus_name': 15,
#    'full_bus_name': '15_EAST TFR PT'},
#   {'destination': '883_25873',
#    'travel_time': 524,
#    'trip_id': 897605,
#    'bus_name': 15,
#    'full_bus_name': '15_EAST TRANSFER'},
#   {'destination': '567_26685',
#    'travel_time': 1336,
#    'trip_id': 889877,
#    'bus_name': 27,
#    'full_bus_name': '27_NORTH TFR PT: VIA JOHNSON'},
#   {'destination': '567_26685',
#    'travel_time': 1336,
#    'trip_id': 904791,
#    'bus_name': 27,
#    'full_bus_name': '27_NORTH TRANSFER: VIA JOHNSON'},
#   {'destination': '883_26945',
#    'travel_time': 1596,
#    'trip_id': 891012,
#    'bus_name': 37,
#    'full_bus_name': '37_PFLAUM RD'},
#   {'destination': '883_26922',
#    'travel_time': 1573,
#    'trip_id': 901140,
#    'bus_name': 37,
#    'full_bus_name': '37_PFLAUM'},
#   {'destination': '883_26471',
#    'travel_time': 1122,
#    'trip_id': 891419,
#    'bus_name': 47,
#    'full_bus_name': '47_CAPITOL SQUARE: VIA PARK'},
#   {'destination': '883_26471',
#    'travel_time': 1122,
#    'trip_id': 901556,
#    'bus_name': 47,
#    'full_bus_name': '47_CAPITOL SQUARE: VIA PARK'},
#   {'destination': '883_25546',
#    'travel_time': 197,
#    'trip_id': 891951,
#    'bus_name': 56,
#    'full_bus_name': '56_NORTH TFR PT'},
#   {'destination': '883_25546',
#    'travel_time': 197,
#    'trip_id': 902104,
#    'bus_name': 56,
#    'full_bus_name': '56_NORTH TRANSFER'},
#   {'destination': '883_26400',
#    'travel_time': 1051,
#    'trip_id': 892019,
#    'bus_name': 57,
#    'full_bus_name': '57_NORTH TFR PT'},
#   {'destination': '883_26400',
#    'travel_time': 1051,
#    'trip_id': 902156,
#    'bus_name': 57,
#    'full_bus_name': '57_NORTH TRANSFER'},
#   {'destination': '883_26925',
#    'travel_time': 1576,
#    'trip_id': 892086,
#    'bus_name': 58,
#    'full_bus_name': '58_CAPITOL SQUARE'},
#   {'destination': '883_26834',
#    'travel_time': 1485,
#    'trip_id': 902226,
#    'bus_name': 58,
#    'full_bus_name': '58_CAPITOL SQUARE'},
#   {'destination': '883_25993',
#    'travel_time': 644,
#    'trip_id': 892771,
#    'bus_name': 71,
#    'full_bus_name': '71_CAPITOL SQUARE'},
#   {'destination': '883_25993',
#    'travel_time': 644,
#    'trip_id': 902908,
#    'bus_name': 71,
#    'full_bus_name': '71_CAPITOL SQUARE'},
#   {'destination': '883_26880',
#    'travel_time': 1531,
#    'trip_id': 892828,
#    'bus_name': 72,
#    'full_bus_name': '72_CAPITOL SQUARE'},
#   {'destination': '883_26880',
#    'travel_time': 1531,
#    'trip_id': 902966,
#    'bus_name': 72,
#    'full_bus_name': '72_CAPITOL SQUARE'}],
#  '883_25435': [{'destination': '1324_25486',
#    'travel_time': 51,
#    'trip_id': 884531,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TFR PT: VIA SHERMAN'},
#   {'destination': '1324_26386',
#    'travel_time': 951,
#    'trip_id': 884544,
#    'bus_name': 2,
#    'full_bus_name': '2_CAPITOL SQUARE'},
#   {'destination': '1324_27286',
#    'travel_time': 1851,
#    'trip_id': 884556,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TFR PT: VIA FORDEM'},
#   {'destination': '1324_26336',
#    'travel_time': 901,
#    'trip_id': 904845,
#    'bus_name': 2,
#    'full_bus_name': '2_CAPITOL SQUARE'},
#   {'destination': '1324_26080',
#    'travel_time': 645,
#    'trip_id': 885035,
#    'bus_name': 3,
#    'full_bus_name': '3_EAST TFR PT: VIA DIVISION'},
#   {'destination': '1324_25912',
#    'travel_time': 477,
#    'trip_id': 895174,
#    'bus_name': 3,
#    'full_bus_name': '3_EAST TRANSFER: VIA DIVISION'},
#   {'destination': '1324_26770',
#    'travel_time': 1335,
#    'trip_id': 885227,
#    'bus_name': 4,
#    'full_bus_name': '4_NORTH TFR PT'},
#   {'destination': '1324_26780',
#    'travel_time': 1345,
#    'trip_id': 895401,
#    'bus_name': 4,
#    'full_bus_name': '4_NORTH TRANSFER'},
#   {'destination': '1324_27032',
#    'travel_time': 1597,
#    'trip_id': 885866,
#    'bus_name': 6,
#    'full_bus_name': '6_E TOWNE: VIA MATC & HAYES'},
#   {'destination': '1324_26021',
#    'travel_time': 586,
#    'trip_id': 885879,
#    'bus_name': 6,
#    'full_bus_name': '6_CAPITOL SQUARE'},
#   {'destination': '1324_27032',
#    'travel_time': 1597,
#    'trip_id': 895993,
#    'bus_name': 6,
#    'full_bus_name': '6_E TOWNE: VIA MADISON COLLEGE & HAYES'},
#   {'destination': '1324_26021',
#    'travel_time': 586,
#    'trip_id': 896006,
#    'bus_name': 6,
#    'full_bus_name': '6_CAPITOL SQUARE'},
#   {'destination': '1324_26439',
#    'travel_time': 1004,
#    'trip_id': 886969,
#    'bus_name': 11,
#    'full_bus_name': '11_DUTCH MILL'},
#   {'destination': '1324_26570',
#    'travel_time': 1135,
#    'trip_id': 887308,
#    'bus_name': 14,
#    'full_bus_name': '14_EAST TFR PT'},
#   {'destination': '1324_26570',
#    'travel_time': 1135,
#    'trip_id': 897473,
#    'bus_name': 14,
#    'full_bus_name': '14_EAST TRANSFER'},
#   {'destination': '1324_25917',
#    'travel_time': 482,
#    'trip_id': 887461,
#    'bus_name': 15,
#    'full_bus_name': '15_EAST TFR PT'},
#   {'destination': '1324_25917',
#    'travel_time': 482,
#    'trip_id': 897605,
#    'bus_name': 15,
#    'full_bus_name': '15_EAST TRANSFER'},
#   {'destination': '1324_26993',
#    'travel_time': 1558,
#    'trip_id': 891012,
#    'bus_name': 37,
#    'full_bus_name': '37_PFLAUM RD'},
#   {'destination': '1324_26980',
#    'travel_time': 1545,
#    'trip_id': 901140,
#    'bus_name': 37,
#    'full_bus_name': '37_PFLAUM'},
#   {'destination': '1324_26515',
#    'travel_time': 1080,
#    'trip_id': 891419,
#    'bus_name': 47,
#    'full_bus_name': '47_CAPITOL SQUARE: VIA PARK'},
#   {'destination': '1324_26515',
#    'travel_time': 1080,
#    'trip_id': 901556,
#    'bus_name': 47,
#    'full_bus_name': '47_CAPITOL SQUARE: VIA PARK'},
#   {'destination': '1324_25601',
#    'travel_time': 166,
#    'trip_id': 891951,
#    'bus_name': 56,
#    'full_bus_name': '56_NORTH TFR PT'},
#   {'destination': '1324_25601',
#    'travel_time': 166,
#    'trip_id': 902104,
#    'bus_name': 56,
#    'full_bus_name': '56_NORTH TRANSFER'},
#   {'destination': '1324_26450',
#    'travel_time': 1015,
#    'trip_id': 892019,
#    'bus_name': 57,
#    'full_bus_name': '57_NORTH TFR PT'},
#   {'destination': '1324_26450',
#    'travel_time': 1015,
#    'trip_id': 902156,
#    'bus_name': 57,
#    'full_bus_name': '57_NORTH TRANSFER'},
#   {'destination': '1324_26980',
#    'travel_time': 1545,
#    'trip_id': 892086,
#    'bus_name': 58,
#    'full_bus_name': '58_CAPITOL SQUARE'},
#   {'destination': '1324_26876',
#    'travel_time': 1441,
#    'trip_id': 902226,
#    'bus_name': 58,
#    'full_bus_name': '58_CAPITOL SQUARE'},
#   {'destination': '1324_26037',
#    'travel_time': 602,
#    'trip_id': 892771,
#    'bus_name': 71,
#    'full_bus_name': '71_CAPITOL SQUARE'},
#   {'destination': '1324_26037',
#    'travel_time': 602,
#    'trip_id': 902908,
#    'bus_name': 71,
#    'full_bus_name': '71_CAPITOL SQUARE'},
#   {'destination': '1324_26930',
#    'travel_time': 1495,
#    'trip_id': 892828,
#    'bus_name': 72,
#    'full_bus_name': '72_CAPITOL SQUARE'},
#   {'destination': '1324_26930',
#    'travel_time': 1495,
#    'trip_id': 902966,
#    'bus_name': 72,
#    'full_bus_name': '72_CAPITOL SQUARE'}],
#  '1324_25486': [{'destination': '1101_25560',
#    'travel_time': 74,
#    'trip_id': 884531,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TFR PT: VIA SHERMAN'},
#   {'destination': '1101_26460',
#    'travel_time': 974,
#    'trip_id': 884544,
#    'bus_name': 2,
#    'full_bus_name': '2_DROP OFFS ONLY'},
#   {'destination': '1101_27360',
#    'travel_time': 1874,
#    'trip_id': 884556,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TFR PT: VIA FORDEM'},
#   {'destination': '1101_26400',
#    'travel_time': 914,
#    'trip_id': 904845,
#    'bus_name': 2,
#    'full_bus_name': '2_DROP OFFS ONLY'},
#   {'destination': '1101_26160',
#    'travel_time': 674,
#    'trip_id': 885035,
#    'bus_name': 3,
#    'full_bus_name': '3_EAST TFR PT: VIA DIVISION'},
#   {'destination': '1101_25980',
#    'travel_time': 494,
#    'trip_id': 895174,
#    'bus_name': 3,
#    'full_bus_name': '3_EAST TRANSFER: VIA DIVISION'},
#   {'destination': '1101_26880',
#    'travel_time': 1394,
#    'trip_id': 885227,
#    'bus_name': 4,
#    'full_bus_name': '4_NORTH TFR PT'},
#   {'destination': '1101_26880',
#    'travel_time': 1394,
#    'trip_id': 895401,
#    'bus_name': 4,
#    'full_bus_name': '4_NORTH TRANSFER'},
#   {'destination': '1790_25588',
#    'travel_time': 102,
#    'trip_id': 885582,
#    'bus_name': 5,
#    'full_bus_name': '5_SOUTH TFR PT'},
#   {'destination': '1790_25588',
#    'travel_time': 102,
#    'trip_id': 895712,
#    'bus_name': 5,
#    'full_bus_name': '5_SOUTH TRANSFER'},
#   {'destination': '1101_27120',
#    'travel_time': 1634,
#    'trip_id': 885866,
#    'bus_name': 6,
#    'full_bus_name': '6_E TOWNE: VIA MATC & HAYES'},
#   {'destination': '1101_26100',
#    'travel_time': 614,
#    'trip_id': 885879,
#    'bus_name': 6,
#    'full_bus_name': '6_DROP OFFS ONLY'},
#   {'destination': '1101_27120',
#    'travel_time': 1634,
#    'trip_id': 895993,
#    'bus_name': 6,
#    'full_bus_name': '6_E TOWNE: VIA MADISON COLLEGE & HAYES'},
#   {'destination': '1101_26100',
#    'travel_time': 614,
#    'trip_id': 896006,
#    'bus_name': 6,
#    'full_bus_name': '6_DROP OFFS ONLY'},
#   {'destination': '1101_26520',
#    'travel_time': 1034,
#    'trip_id': 886969,
#    'bus_name': 11,
#    'full_bus_name': '11_DUTCH MILL'},
#   {'destination': '1101_26640',
#    'travel_time': 1154,
#    'trip_id': 887308,
#    'bus_name': 14,
#    'full_bus_name': '14_EAST TFR PT'},
#   {'destination': '1101_26640',
#    'travel_time': 1154,
#    'trip_id': 897473,
#    'bus_name': 14,
#    'full_bus_name': '14_EAST TRANSFER'},
#   {'destination': '1101_25980',
#    'travel_time': 494,
#    'trip_id': 887461,
#    'bus_name': 15,
#    'full_bus_name': '15_EAST TFR PT'},
#   {'destination': '1101_25980',
#    'travel_time': 494,
#    'trip_id': 897605,
#    'bus_name': 15,
#    'full_bus_name': '15_EAST TRANSFER'},
#   {'destination': '1101_26187',
#    'travel_time': 701,
#    'trip_id': 888756,
#    'bus_name': 19,
#    'full_bus_name': '19_DUNNS MARSH: VIA MIDVALE'},
#   {'destination': '1101_26187',
#    'travel_time': 701,
#    'trip_id': 898919,
#    'bus_name': 19,
#    'full_bus_name': '19_DUNNS MARSH: VIA MIDVALE'},
#   {'destination': '1101_26229',
#    'travel_time': 743,
#    'trip_id': 904774,
#    'bus_name': 23,
#    'full_bus_name': '23_SUN PRAIRIE: VIA AMERICAN CENTER'},
#   {'destination': '1790_27223',
#    'travel_time': 1737,
#    'trip_id': 889883,
#    'bus_name': 27,
#    'full_bus_name': '27_UW CAMPUS: VIA WASHINGTON AV'},
#   {'destination': '1790_27223',
#    'travel_time': 1737,
#    'trip_id': 904797,
#    'bus_name': 27,
#    'full_bus_name': '27_U.W. CAMPUS: VIA WASHINGTON'},
#   {'destination': '1101_27060',
#    'travel_time': 1574,
#    'trip_id': 891012,
#    'bus_name': 37,
#    'full_bus_name': '37_PFLAUM RD'},
#   {'destination': '1101_27060',
#    'travel_time': 1574,
#    'trip_id': 901140,
#    'bus_name': 37,
#    'full_bus_name': '37_PFLAUM'},
#   {'destination': '1790_26724',
#    'travel_time': 1238,
#    'trip_id': 891400,
#    'bus_name': 47,
#    'full_bus_name': '47_ARBOR HILLS: VIA WEST WASH'},
#   {'destination': '1101_26580',
#    'travel_time': 1094,
#    'trip_id': 891419,
#    'bus_name': 47,
#    'full_bus_name': '47_DROP OFFS ONLY'},
#   {'destination': '1790_26724',
#    'travel_time': 1238,
#    'trip_id': 901553,
#    'bus_name': 47,
#    'full_bus_name': '47_ARBOR HILLS: VIA WASHINGTON'},
#   {'destination': '1101_26580',
#    'travel_time': 1094,
#    'trip_id': 901556,
#    'bus_name': 47,
#    'full_bus_name': '47_DROP OFFS ONLY'},
#   {'destination': '1101_25680',
#    'travel_time': 194,
#    'trip_id': 891951,
#    'bus_name': 56,
#    'full_bus_name': '56_NORTH TFR PT'},
#   {'destination': '1101_25680',
#    'travel_time': 194,
#    'trip_id': 902104,
#    'bus_name': 56,
#    'full_bus_name': '56_NORTH TRANSFER'},
#   {'destination': '1101_26520',
#    'travel_time': 1034,
#    'trip_id': 892019,
#    'bus_name': 57,
#    'full_bus_name': '57_NORTH TFR PT'},
#   {'destination': '1101_26520',
#    'travel_time': 1034,
#    'trip_id': 902156,
#    'bus_name': 57,
#    'full_bus_name': '57_NORTH TRANSFER'},
#   {'destination': '1101_27060',
#    'travel_time': 1574,
#    'trip_id': 892086,
#    'bus_name': 58,
#    'full_bus_name': '58_DROP OFFS ONLY'},
#   {'destination': '1101_26940',
#    'travel_time': 1454,
#    'trip_id': 902226,
#    'bus_name': 58,
#    'full_bus_name': '58_DROP OFFS ONLY'},
#   {'destination': '1101_26100',
#    'travel_time': 614,
#    'trip_id': 892771,
#    'bus_name': 71,
#    'full_bus_name': '71_DROP OFFS ONLY'},
#   {'destination': '1101_26100',
#    'travel_time': 614,
#    'trip_id': 902908,
#    'bus_name': 71,
#    'full_bus_name': '71_DROP OFFS ONLY'},
#   {'destination': '1101_27000',
#    'travel_time': 1514,
#    'trip_id': 892828,
#    'bus_name': 72,
#    'full_bus_name': '72_DROP OFFS ONLY'},
#   {'destination': '1101_27000',
#    'travel_time': 1514,
#    'trip_id': 902966,
#    'bus_name': 72,
#    'full_bus_name': '72_DROP OFFS ONLY'}],
#  '1101_25560': [{'destination': '1787_25603',
#    'travel_time': 43,
#    'trip_id': 884531,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TFR PT: VIA SHERMAN'},
#   {'destination': '1787_27403',
#    'travel_time': 1843,
#    'trip_id': 884556,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TFR PT: VIA FORDEM'},
#   {'destination': '1787_27410',
#    'travel_time': 1850,
#    'trip_id': 904857,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TRANSFER: VIA FORDEM'},
#   {'destination': '1823_26201',
#    'travel_time': 641,
#    'trip_id': 885035,
#    'bus_name': 3,
#    'full_bus_name': '3_EAST TFR PT: VIA DIVISION'},
#   {'destination': '1823_26015',
#    'travel_time': 455,
#    'trip_id': 895174,
#    'bus_name': 3,
#    'full_bus_name': '3_EAST TRANSFER: VIA DIVISION'},
#   {'destination': '1823_26921',
#    'travel_time': 1361,
#    'trip_id': 885227,
#    'bus_name': 4,
#    'full_bus_name': '4_NORTH TFR PT'},
#   {'destination': '1823_26921',
#    'travel_time': 1361,
#    'trip_id': 895401,
#    'bus_name': 4,
#    'full_bus_name': '4_NORTH TRANSFER'},
#   {'destination': '1787_26217',
#    'travel_time': 657,
#    'trip_id': 885544,
#    'bus_name': 5,
#    'full_bus_name': '5_EAST TFR PT'},
#   {'destination': '1787_26217',
#    'travel_time': 657,
#    'trip_id': 895696,
#    'bus_name': 5,
#    'full_bus_name': '5_EAST TRANSFER'},
#   {'destination': '1787_27167',
#    'travel_time': 1607,
#    'trip_id': 885866,
#    'bus_name': 6,
#    'full_bus_name': '6_E TOWNE: VIA MATC & HAYES'},
#   {'destination': '1787_27167',
#    'travel_time': 1607,
#    'trip_id': 895993,
#    'bus_name': 6,
#    'full_bus_name': '6_E TOWNE: VIA MADISON COLLEGE & HAYES'},
#   {'destination': '1872_26552',
#    'travel_time': 992,
#    'trip_id': 886969,
#    'bus_name': 11,
#    'full_bus_name': '11_DUTCH MILL'},
#   {'destination': '1787_26047',
#    'travel_time': 487,
#    'trip_id': 887017,
#    'bus_name': 12,
#    'full_bus_name': '12_WEST TFR PT'},
#   {'destination': '1787_26047',
#    'travel_time': 487,
#    'trip_id': 897163,
#    'bus_name': 12,
#    'full_bus_name': '12_WEST TRANSFER'},
#   {'destination': '1787_26679',
#    'travel_time': 1119,
#    'trip_id': 887308,
#    'bus_name': 14,
#    'full_bus_name': '14_EAST TFR PT'},
#   {'destination': '1787_26679',
#    'travel_time': 1119,
#    'trip_id': 897473,
#    'bus_name': 14,
#    'full_bus_name': '14_EAST TRANSFER'},
#   {'destination': '1787_26019',
#    'travel_time': 459,
#    'trip_id': 887461,
#    'bus_name': 15,
#    'full_bus_name': '15_EAST TFR PT'},
#   {'destination': '1787_26019',
#    'travel_time': 459,
#    'trip_id': 897605,
#    'bus_name': 15,
#    'full_bus_name': '15_EAST TRANSFER'},
#   {'destination': '1872_26257',
#    'travel_time': 697,
#    'trip_id': 888756,
#    'bus_name': 19,
#    'full_bus_name': '19_DUNNS MARSH: VIA MIDVALE'},
#   {'destination': '1787_25620',
#    'travel_time': 60,
#    'trip_id': 888795,
#    'bus_name': 19,
#    'full_bus_name': '19_DROP OFFS ONLY'},
#   {'destination': '1872_26257',
#    'travel_time': 697,
#    'trip_id': 898919,
#    'bus_name': 19,
#    'full_bus_name': '19_DUNNS MARSH: VIA MIDVALE'},
#   {'destination': '1787_25620',
#    'travel_time': 60,
#    'trip_id': 898923,
#    'bus_name': 19,
#    'full_bus_name': '19_DROP OFFS ONLY'},
#   {'destination': '1787_26266',
#    'travel_time': 706,
#    'trip_id': 904774,
#    'bus_name': 23,
#    'full_bus_name': '23_SUN PRAIRIE: VIA AMERICAN CENTER'},
#   {'destination': '1787_26254',
#    'travel_time': 694,
#    'trip_id': 889662,
#    'bus_name': 25,
#    'full_bus_name': '25_AMERICAN CTR'},
#   {'destination': '1787_26261',
#    'travel_time': 701,
#    'trip_id': 904907,
#    'bus_name': 25,
#    'full_bus_name': '25_AMERICAN CENTER'},
#   {'destination': '1787_27099',
#    'travel_time': 1539,
#    'trip_id': 891012,
#    'bus_name': 37,
#    'full_bus_name': '37_PFLAUM RD'},
#   {'destination': '1787_27099',
#    'travel_time': 1539,
#    'trip_id': 901140,
#    'bus_name': 37,
#    'full_bus_name': '37_PFLAUM'},
#   {'destination': '1787_26620',
#    'travel_time': 1060,
#    'trip_id': 891400,
#    'bus_name': 47,
#    'full_bus_name': '47_ARBOR HILLS: VIA WEST WASH'},
#   {'destination': '1787_26620',
#    'travel_time': 1060,
#    'trip_id': 901553,
#    'bus_name': 47,
#    'full_bus_name': '47_ARBOR HILLS: VIA WASHINGTON'},
#   {'destination': '1787_25719',
#    'travel_time': 159,
#    'trip_id': 891951,
#    'bus_name': 56,
#    'full_bus_name': '56_NORTH TFR PT'},
#   {'destination': '1787_25719',
#    'travel_time': 159,
#    'trip_id': 902104,
#    'bus_name': 56,
#    'full_bus_name': '56_NORTH TRANSFER'},
#   {'destination': '1787_26559',
#    'travel_time': 999,
#    'trip_id': 892019,
#    'bus_name': 57,
#    'full_bus_name': '57_NORTH TFR PT'},
#   {'destination': '1787_26559',
#    'travel_time': 999,
#    'trip_id': 902156,
#    'bus_name': 57,
#    'full_bus_name': '57_NORTH TRANSFER'},
#   {'destination': '1787_27247',
#    'travel_time': 1687,
#    'trip_id': 892073,
#    'bus_name': 58,
#    'full_bus_name': '58_GREENTREE: VIA WATTS'},
#   {'destination': '1787_27247',
#    'travel_time': 1687,
#    'trip_id': 902224,
#    'bus_name': 58,
#    'full_bus_name': '58_GREENTREE: VIA WATTS'},
#   {'destination': '1787_26339',
#    'travel_time': 779,
#    'trip_id': 892761,
#    'bus_name': 71,
#    'full_bus_name': '71_MIDDLETON: VIA DISCOVERY'},
#   {'destination': '1787_26339',
#    'travel_time': 779,
#    'trip_id': 902899,
#    'bus_name': 71,
#    'full_bus_name': '71_MIDDLETON: VIA DISCOVERY'},
#   {'destination': '1787_27247',
#    'travel_time': 1687,
#    'trip_id': 892817,
#    'bus_name': 72,
#    'full_bus_name': '72_MIDDLETON: VIA ALLEN'},
#   {'destination': '1787_27247',
#    'travel_time': 1687,
#    'trip_id': 902956,
#    'bus_name': 72,
#    'full_bus_name': '72_MIDDLETON: VIA ALLEN'},
#   {'destination': '1787_27360',
#    'travel_time': 1800,
#    'trip_id': 893028,
#    'bus_name': 75,
#    'full_bus_name': '75_DROP OFFS ONLY'},
#   {'destination': '1787_27360',
#    'travel_time': 1800,
#    'trip_id': 903166,
#    'bus_name': 75,
#    'full_bus_name': '75_DROP OFFS ONLY'}],
#  '1787_25603': [{'destination': '1495_25633',
#    'travel_time': 30,
#    'trip_id': 884531,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TFR PT: VIA SHERMAN'},
#   {'destination': '1495_27433',
#    'travel_time': 1830,
#    'trip_id': 884556,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TFR PT: VIA FORDEM'},
#   {'destination': '1100_25860',
#    'travel_time': 257,
#    'trip_id': 885084,
#    'bus_name': 3,
#    'full_bus_name': '3_WEST TFR PT'},
#   {'destination': '1100_25740',
#    'travel_time': 137,
#    'trip_id': 895211,
#    'bus_name': 3,
#    'full_bus_name': '3_WEST TRANSFER'},
#   {'destination': '1100_26940',
#    'travel_time': 1337,
#    'trip_id': 885259,
#    'bus_name': 4,
#    'full_bus_name': '4_SOUTH TFR PT'},
#   {'destination': '1100_27000',
#    'travel_time': 1397,
#    'trip_id': 895433,
#    'bus_name': 4,
#    'full_bus_name': '4_SOUTH TRANSFER'},
#   {'destination': '1495_26258',
#    'travel_time': 655,
#    'trip_id': 885544,
#    'bus_name': 5,
#    'full_bus_name': '5_EAST TFR PT'},
#   {'destination': '1495_26258',
#    'travel_time': 655,
#    'trip_id': 895696,
#    'bus_name': 5,
#    'full_bus_name': '5_EAST TRANSFER'},
#   {'destination': '1323_27213',
#    'travel_time': 1610,
#    'trip_id': 885866,
#    'bus_name': 6,
#    'full_bus_name': '6_E TOWNE: VIA MATC & HAYES'},
#   {'destination': '1323_27213',
#    'travel_time': 1610,
#    'trip_id': 895993,
#    'bus_name': 6,
#    'full_bus_name': '6_E TOWNE: VIA MADISON COLLEGE & HAYES'},
#   {'destination': '1100_26113',
#    'travel_time': 510,
#    'trip_id': 887017,
#    'bus_name': 12,
#    'full_bus_name': '12_WEST TFR PT'},
#   {'destination': '1100_26113',
#    'travel_time': 510,
#    'trip_id': 897163,
#    'bus_name': 12,
#    'full_bus_name': '12_WEST TRANSFER'},
#   {'destination': '1323_26717',
#    'travel_time': 1114,
#    'trip_id': 887308,
#    'bus_name': 14,
#    'full_bus_name': '14_EAST TFR PT'},
#   {'destination': '1323_26717',
#    'travel_time': 1114,
#    'trip_id': 897473,
#    'bus_name': 14,
#    'full_bus_name': '14_EAST TRANSFER'},
#   {'destination': '1323_26057',
#    'travel_time': 454,
#    'trip_id': 887461,
#    'bus_name': 15,
#    'full_bus_name': '15_EAST TFR PT'},
#   {'destination': '1323_26057',
#    'travel_time': 454,
#    'trip_id': 897605,
#    'bus_name': 15,
#    'full_bus_name': '15_EAST TRANSFER'},
#   {'destination': '1100_26051',
#    'travel_time': 448,
#    'trip_id': 888756,
#    'bus_name': 19,
#    'full_bus_name': '19_DUNNS MARSH: VIA MIDVALE'},
#   {'destination': '1100_26051',
#    'travel_time': 448,
#    'trip_id': 898919,
#    'bus_name': 19,
#    'full_bus_name': '19_DUNNS MARSH: VIA MIDVALE'},
#   {'destination': '1323_26302',
#    'travel_time': 699,
#    'trip_id': 904774,
#    'bus_name': 23,
#    'full_bus_name': '23_SUN PRAIRIE: VIA AMERICAN CENTER'},
#   {'destination': '1323_26287',
#    'travel_time': 684,
#    'trip_id': 889662,
#    'bus_name': 25,
#    'full_bus_name': '25_AMERICAN CTR'},
#   {'destination': '1323_26301',
#    'travel_time': 698,
#    'trip_id': 904907,
#    'bus_name': 25,
#    'full_bus_name': '25_AMERICAN CENTER'},
#   {'destination': '1323_27137',
#    'travel_time': 1534,
#    'trip_id': 891012,
#    'bus_name': 37,
#    'full_bus_name': '37_PFLAUM RD'},
#   {'destination': '1323_27137',
#    'travel_time': 1534,
#    'trip_id': 901140,
#    'bus_name': 37,
#    'full_bus_name': '37_PFLAUM'},
#   {'destination': '1100_26659',
#    'travel_time': 1056,
#    'trip_id': 891400,
#    'bus_name': 47,
#    'full_bus_name': '47_ARBOR HILLS: VIA WEST WASH'},
#   {'destination': '1100_26659',
#    'travel_time': 1056,
#    'trip_id': 901553,
#    'bus_name': 47,
#    'full_bus_name': '47_ARBOR HILLS: VIA WASHINGTON'},
#   {'destination': '1323_25757',
#    'travel_time': 154,
#    'trip_id': 891951,
#    'bus_name': 56,
#    'full_bus_name': '56_NORTH TFR PT'},
#   {'destination': '1323_25757',
#    'travel_time': 154,
#    'trip_id': 902104,
#    'bus_name': 56,
#    'full_bus_name': '56_NORTH TRANSFER'},
#   {'destination': '1323_26597',
#    'travel_time': 994,
#    'trip_id': 892019,
#    'bus_name': 57,
#    'full_bus_name': '57_NORTH TFR PT'},
#   {'destination': '1323_26597',
#    'travel_time': 994,
#    'trip_id': 902156,
#    'bus_name': 57,
#    'full_bus_name': '57_NORTH TRANSFER'},
#   {'destination': '1100_27313',
#    'travel_time': 1710,
#    'trip_id': 892073,
#    'bus_name': 58,
#    'full_bus_name': '58_GREENTREE: VIA WATTS'},
#   {'destination': '1100_27313',
#    'travel_time': 1710,
#    'trip_id': 902224,
#    'bus_name': 58,
#    'full_bus_name': '58_GREENTREE: VIA WATTS'},
#   {'destination': '1100_26398',
#    'travel_time': 795,
#    'trip_id': 892761,
#    'bus_name': 71,
#    'full_bus_name': '71_MIDDLETON: VIA DISCOVERY'},
#   {'destination': '1100_26398',
#    'travel_time': 795,
#    'trip_id': 902899,
#    'bus_name': 71,
#    'full_bus_name': '71_MIDDLETON: VIA DISCOVERY'},
#   {'destination': '1100_27313',
#    'travel_time': 1710,
#    'trip_id': 892817,
#    'bus_name': 72,
#    'full_bus_name': '72_MIDDLETON: VIA ALLEN'},
#   {'destination': '1100_27313',
#    'travel_time': 1710,
#    'trip_id': 902956,
#    'bus_name': 72,
#    'full_bus_name': '72_MIDDLETON: VIA ALLEN'}],
#  '1495_25633': [{'destination': '1261_25684',
#    'travel_time': 51,
#    'trip_id': 884531,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TFR PT: VIA SHERMAN'},
#   {'destination': '1261_27484',
#    'travel_time': 1851,
#    'trip_id': 884556,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TFR PT: VIA FORDEM'},
#   {'destination': '1261_26326',
#    'travel_time': 693,
#    'trip_id': 885544,
#    'bus_name': 5,
#    'full_bus_name': '5_EAST TFR PT'},
#   {'destination': '1261_26326',
#    'travel_time': 693,
#    'trip_id': 895696,
#    'bus_name': 5,
#    'full_bus_name': '5_EAST TRANSFER'}],
#  '1261_25684': [{'destination': '1831_25743',
#    'travel_time': 59,
#    'trip_id': 884531,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TFR PT: VIA SHERMAN'},
#   {'destination': '1831_27543',
#    'travel_time': 1859,
#    'trip_id': 884556,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TFR PT: VIA FORDEM'},
#   {'destination': '1831_26405',
#    'travel_time': 721,
#    'trip_id': 885544,
#    'bus_name': 5,
#    'full_bus_name': '5_EAST TFR PT'},
#   {'destination': '1831_26405',
#    'travel_time': 721,
#    'trip_id': 895696,
#    'bus_name': 5,
#    'full_bus_name': '5_EAST TRANSFER'}],
#  '1831_25743': [{'destination': '1397_25778',
#    'travel_time': 35,
#    'trip_id': 884531,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TFR PT: VIA SHERMAN'},
#   {'destination': '1397_27578',
#    'travel_time': 1835,
#    'trip_id': 884556,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TFR PT: VIA FORDEM'},
#   {'destination': '1397_26451',
#    'travel_time': 708,
#    'trip_id': 885544,
#    'bus_name': 5,
#    'full_bus_name': '5_EAST TFR PT'},
#   {'destination': '1397_26451',
#    'travel_time': 708,
#    'trip_id': 895696,
#    'bus_name': 5,
#    'full_bus_name': '5_EAST TRANSFER'},
#   {'destination': '1397_26822',
#    'travel_time': 1079,
#    'trip_id': 889877,
#    'bus_name': 27,
#    'full_bus_name': '27_NORTH TFR PT: VIA JOHNSON'},
#   {'destination': '1397_26822',
#    'travel_time': 1079,
#    'trip_id': 904791,
#    'bus_name': 27,
#    'full_bus_name': '27_NORTH TRANSFER: VIA JOHNSON'}],
#  '1397_25778': [{'destination': '1121_25802',
#    'travel_time': 24,
#    'trip_id': 884531,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TFR PT: VIA SHERMAN'},
#   {'destination': '1121_27602',
#    'travel_time': 1824,
#    'trip_id': 884556,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TFR PT: VIA FORDEM'},
#   {'destination': '1121_26483',
#    'travel_time': 705,
#    'trip_id': 885544,
#    'bus_name': 5,
#    'full_bus_name': '5_EAST TFR PT'},
#   {'destination': '1121_26483',
#    'travel_time': 705,
#    'trip_id': 895696,
#    'bus_name': 5,
#    'full_bus_name': '5_EAST TRANSFER'},
#   {'destination': '1121_26841',
#    'travel_time': 1063,
#    'trip_id': 889877,
#    'bus_name': 27,
#    'full_bus_name': '27_NORTH TFR PT: VIA JOHNSON'},
#   {'destination': '1121_26841',
#    'travel_time': 1063,
#    'trip_id': 904791,
#    'bus_name': 27,
#    'full_bus_name': '27_NORTH TRANSFER: VIA JOHNSON'}],
#  '1121_25802': [{'destination': '1151_25847',
#    'travel_time': 45,
#    'trip_id': 884531,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TFR PT: VIA SHERMAN'},
#   {'destination': '1151_27647',
#    'travel_time': 1845,
#    'trip_id': 884556,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TFR PT: VIA FORDEM'},
#   {'destination': '1151_26543',
#    'travel_time': 741,
#    'trip_id': 885544,
#    'bus_name': 5,
#    'full_bus_name': '5_EAST TFR PT'},
#   {'destination': '1151_26543',
#    'travel_time': 741,
#    'trip_id': 895696,
#    'bus_name': 5,
#    'full_bus_name': '5_EAST TRANSFER'},
#   {'destination': '1151_26877',
#    'travel_time': 1075,
#    'trip_id': 889877,
#    'bus_name': 27,
#    'full_bus_name': '27_NORTH TFR PT: VIA JOHNSON'},
#   {'destination': '1151_26877',
#    'travel_time': 1075,
#    'trip_id': 904791,
#    'bus_name': 27,
#    'full_bus_name': '27_NORTH TRANSFER: VIA JOHNSON'}],
#  '1151_25847': [{'destination': '1209_25920',
#    'travel_time': 73,
#    'trip_id': 884531,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TFR PT: VIA SHERMAN'},
#   {'destination': '1209_27720',
#    'travel_time': 1873,
#    'trip_id': 884556,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TFR PT: VIA FORDEM'},
#   {'destination': '1209_26640',
#    'travel_time': 793,
#    'trip_id': 885544,
#    'bus_name': 5,
#    'full_bus_name': '5_EAST TFR PT'},
#   {'destination': '1209_26640',
#    'travel_time': 793,
#    'trip_id': 895696,
#    'bus_name': 5,
#    'full_bus_name': '5_EAST TRANSFER'},
#   {'destination': '1209_26940',
#    'travel_time': 1093,
#    'trip_id': 889877,
#    'bus_name': 27,
#    'full_bus_name': '27_NORTH TFR PT: VIA JOHNSON'},
#   {'destination': '1209_26940',
#    'travel_time': 1093,
#    'trip_id': 904791,
#    'bus_name': 27,
#    'full_bus_name': '27_NORTH TRANSFER: VIA JOHNSON'}],
#  '1209_25920': [{'destination': '1767_25985',
#    'travel_time': 65,
#    'trip_id': 884531,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TFR PT: VIA SHERMAN'},
#   {'destination': '1325_27771',
#    'travel_time': 1851,
#    'trip_id': 884556,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TFR PT: VIA FORDEM'},
#   {'destination': '1325_26692',
#    'travel_time': 772,
#    'trip_id': 885544,
#    'bus_name': 5,
#    'full_bus_name': '5_EAST TFR PT'},
#   {'destination': '1325_26692',
#    'travel_time': 772,
#    'trip_id': 895696,
#    'bus_name': 5,
#    'full_bus_name': '5_EAST TRANSFER'},
#   {'destination': '1325_26999',
#    'travel_time': 1079,
#    'trip_id': 889877,
#    'bus_name': 27,
#    'full_bus_name': '27_NORTH TFR PT: VIA JOHNSON'},
#   {'destination': '1325_26999',
#    'travel_time': 1079,
#    'trip_id': 904791,
#    'bus_name': 27,
#    'full_bus_name': '27_NORTH TRANSFER: VIA JOHNSON'}],
#  '1767_25985': [{'destination': '1157_26043',
#    'travel_time': 58,
#    'trip_id': 884531,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TFR PT: VIA SHERMAN'}],
#  '1157_26043': [{'destination': '1577_26104',
#    'travel_time': 61,
#    'trip_id': 884531,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TFR PT: VIA SHERMAN'}],
#  '1577_26104': [{'destination': '1329_26160',
#    'travel_time': 56,
#    'trip_id': 884531,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TFR PT: VIA SHERMAN'}],
#  '1329_26160': [{'destination': '1533_26219',
#    'travel_time': 59,
#    'trip_id': 884531,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TFR PT: VIA SHERMAN'}],
#  '1533_26219': [{'destination': '1717_26256',
#    'travel_time': 37,
#    'trip_id': 884531,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TFR PT'}],
#  '1717_26256': [{'destination': '1923_26296',
#    'travel_time': 40,
#    'trip_id': 884531,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TFR PT'},
#   {'destination': '1923_28052',
#    'travel_time': 1796,
#    'trip_id': 884556,
#    'bus_name': 2,
#    'full_bus_name': '2_NORTH TFR PT'},
#   {'destination': '1923_28094',
# ...
#   {'destination': '1398_28872',
#    'travel_time': 395,
#    'trip_id': 901236,
#    'bus_name': 38,
#    'full_bus_name': '38_TO U.W. HOSPITAL: VIA DENNETT & ATWOOD: VIA WILSON'}],
#  '1398_28508': [{'destination': '1388_28535',
#    'travel_time': 27,
#    'trip_id': 885085,
#    'bus_name': 3,
#    'full_bus_name': '3_WEST TFR PT: VIA WINNEBAGO'},
#   {'destination': '1388_28899',
#    'travel_time': 391,
#    'trip_id': 891093,
#    'bus_name': 38,
#    'full_bus_name': '38_TO UW HOSPITAL: VIA ATWOOD: VIA WILSON'},
#   {'destination': '1388_28899',
#    'travel_time': 391,
#    'trip_id': 901236,
#    'bus_name': 38,
#    'full_bus_name': '38_TO U.W. HOSPITAL: VIA DENNETT & ATWOOD: VIA WILSON'}],
#  '1388_28535': [{'destination': '1712_28570',
#    'travel_time': 35,
#    'trip_id': 885085,
#    'bus_name': 3,
#    'full_bus_name': '3_WEST TFR PT: VIA WINNEBAGO'},
#   {'destination': '1784_28980',
#    'travel_time': 445,
#    'trip_id': 891093,
#    'bus_name': 38,
#    'full_bus_name': '38_TO UW HOSPITAL: VIA WILSON'},
#   {'destination': '1784_28980',
#    'travel_time': 445,
#    'trip_id': 901236,
#    'bus_name': 38,
#    'full_bus_name': '38_TO U.W. HOSPITAL: VIA WILSON'}],
#  '1712_28570': [{'destination': '1188_28620',
#    'travel_time': 50,
#    'trip_id': 885085,
#    'bus_name': 3,
#    'full_bus_name': '3_WEST TFR PT: VIA WINNEBAGO'}],
#  '1188_28620': [{'destination': '1830_28648',
#    'travel_time': 28,
#    'trip_id': 885085,
#    'bus_name': 3,
#    'full_bus_name': '3_WEST TFR PT: VIA WINNEBAGO'},
#   {'destination': '1830_29682',
#    'travel_time': 1062,
#    'trip_id': 885287,
#    'bus_name': 4,
#    'full_bus_name': '4_SOUTH TFR PT'},
#   {'destination': '1830_29622',
#    'travel_time': 1002,
#    'trip_id': 895429,
#    'bus_name': 4,
#    'full_bus_name': '4_SOUTH TRANSFER'}],
#  '1830_28648': [{'destination': '1472_28681',
#    'travel_time': 33,
#    'trip_id': 885085,
#    'bus_name': 3,
#    'full_bus_name': '3_WEST TFR PT: VIA WINNEBAGO'},
#   {'destination': '1472_29732',
#    'travel_time': 1084,
#    'trip_id': 885287,
#    'bus_name': 4,
#    'full_bus_name': '4_SOUTH TFR PT'},
#   {'destination': '1472_29672',
#    'travel_time': 1024,
#    'trip_id': 895429,
#    'bus_name': 4,
#    'full_bus_name': '4_SOUTH TRANSFER'}],
#  '1472_28681': [{'destination': '1208_28712',
#    'travel_time': 31,
#    'trip_id': 885085,
#    'bus_name': 3,
#    'full_bus_name': '3_WEST TFR PT: VIA WINNEBAGO'},
#   {'destination': '1208_29778',
#    'travel_time': 1097,
#    'trip_id': 885287,
#    'bus_name': 4,
#    'full_bus_name': '4_SOUTH TFR PT'},
#   {'destination': '1208_29718',
#    'travel_time': 1037,
#    'trip_id': 895429,
#    'bus_name': 4,
#    'full_bus_name': '4_SOUTH TRANSFER'}],
#  '1208_28712': [{'destination': '1526_28752',
#    'travel_time': 40,
#    'trip_id': 885085,
#    'bus_name': 3,
#    'full_bus_name': '3_WEST TFR PT: VIA WINNEBAGO'},
#   {'destination': '1526_29838',
#    'travel_time': 1126,
#    'trip_id': 885287,
#    'bus_name': 4,
#    'full_bus_name': '4_SOUTH TFR PT'},
#   {'destination': '1526_29778',
#    'travel_time': 1066,
#    'trip_id': 895429,
#    'bus_name': 4,
#    'full_bus_name': '4_SOUTH TRANSFER'}],
#  '1526_28752': [{'destination': '1530_28801',
#    'travel_time': 49,
#    'trip_id': 885085,
#    'bus_name': 3,
#    'full_bus_name': '3_WEST TFR PT'},
#   {'destination': '1530_28832',
#    'travel_time': 80,
#    'trip_id': 895210,
#    'bus_name': 3,
#    'full_bus_name': '3_WEST TRANSFER'},
#   {'destination': '1530_29912',
#    'travel_time': 1160,
#    'trip_id': 885287,
#    'bus_name': 4,
#    'full_bus_name': '4_SOUTH TFR PT'},
#   {'destination': '1530_29852',
#    'travel_time': 1100,
#    'trip_id': 895429,
#    'bus_name': 4,
#    'full_bus_name': '4_SOUTH TRANSFER'}],
#  '1530_28801': [{'destination': '1750_28824',
#    'travel_time': 23,
#    'trip_id': 885085,
#    'bus_name': 3,
#    'full_bus_name': '3_WEST TFR PT'},
#   {'destination': '1750_28867',
#    'travel_time': 66,
#    'trip_id': 895210,
#    'bus_name': 3,
#    'full_bus_name': '3_WEST TRANSFER'},
#   {'destination': '1750_29947',
#    'travel_time': 1146,
#    'trip_id': 885287,
#    'bus_name': 4,
#    'full_bus_name': '4_SOUTH TFR PT'},
#   {'destination': '1750_29887',
#    'travel_time': 1086,
#    'trip_id': 895429,
#    'bus_name': 4,
#    'full_bus_name': '4_SOUTH TRANSFER'},
#   {'destination': '1750_30194',
#    'travel_time': 1393,
#    'trip_id': 891082,
#    'bus_name': 38,
#    'full_bus_name': '38_TO UW HOSPITAL: VIA WILSON'},
#   {'destination': '1750_29294',
#    'travel_time': 493,
#    'trip_id': 891093,
#    'bus_name': 38,
#    'full_bus_name': '38_TO UW HOSPITAL: VIA WILSON'},
#   {'destination': '1750_29054',
#    'travel_time': 253,
#    'trip_id': 891096,
#    'bus_name': 38,
#    'full_bus_name': '38_TO UW HOSPITAL: VIA WILSON'},
#   {'destination': '1750_29894',
#    'travel_time': 1093,
#    'trip_id': 891097,
#    'bus_name': 38,
#    'full_bus_name': '38_TO UW HOSPITAL: VIA WILSON'},
#   {'destination': '1750_29894',
#    'travel_time': 1093,
#    'trip_id': 901232,
#    'bus_name': 38,
#    'full_bus_name': '38_TO U.W. HOSPITAL: VIA WILSON'},
#   {'destination': '1750_29054',
#    'travel_time': 253,
#    'trip_id': 901233,
#    'bus_name': 38,
#    'full_bus_name': '38_TO U.W. HOSPITAL: VIA WILSON'},
#   {'destination': '1750_29294',
#    'travel_time': 493,
#    'trip_id': 901236,
#    'bus_name': 38,
#    'full_bus_name': '38_TO U.W. HOSPITAL: VIA WILSON'},
#   {'destination': '1750_30194',
#    'travel_time': 1393,
#    'trip_id': 901247,
#    'bus_name': 38,
#    'full_bus_name': '38_TO U.W. HOSPITAL: VIA WILSON'}],
#  '1750_28824': [{'destination': '1878_28860',
#    'travel_time': 36,
#    'trip_id': 885085,
#    'bus_name': 3,
#    'full_bus_name': '3_WEST TFR PT'},
#   {'destination': '1878_28920',
#    'travel_time': 96,
#    'trip_id': 895210,
#    'bus_name': 3,
#    'full_bus_name': '3_WEST TRANSFER'},
#   {'destination': '1878_30000',
#    'travel_time': 1176,
#    'trip_id': 885287,
#    'bus_name': 4,
#    'full_bus_name': '4_SOUTH TFR PT'},
#   {'destination': '1878_29940',
#    'travel_time': 1116,
#    'trip_id': 895429,
#    'bus_name': 4,
#    'full_bus_name': '4_SOUTH TRANSFER'},
#   {'destination': '1878_30240',
#    'travel_time': 1416,
#    'trip_id': 891082,
#    'bus_name': 38,
#    'full_bus_name': '38_TO UW HOSPITAL: VIA WILSON'},
#   {'destination': '1878_29340',
#    'travel_time': 516,
#    'trip_id': 891093,
#    'bus_name': 38,
#    'full_bus_name': '38_TO UW HOSPITAL: VIA WILSON'},
#   {'destination': '1878_29100',
#    'travel_time': 276,
#    'trip_id': 891096,
#    'bus_name': 38,
#    'full_bus_name': '38_TO UW HOSPITAL: VIA WILSON'},
#   {'destination': '1878_29940',
#    'travel_time': 1116,
#    'trip_id': 891097,
#    'bus_name': 38,
#    'full_bus_name': '38_TO UW HOSPITAL: VIA WILSON'},
#   {'destination': '1878_29940',
#    'travel_time': 1116,
#    'trip_id': 901232,
#    'bus_name': 38,
#    'full_bus_name': '38_TO U.W. HOSPITAL: VIA WILSON'},
#   {'destination': '1878_29100',
#    'travel_time': 276,
#    'trip_id': 901233,
#    'bus_name': 38,
#    'full_bus_name': '38_TO U.W. HOSPITAL: VIA WILSON'},
#   {'destination': '1878_29340',
#    'travel_time': 516,
#    'trip_id': 901236,
#    'bus_name': 38,
#    'full_bus_name': '38_TO U.W. HOSPITAL: VIA WILSON'},
#   {'destination': '1878_30240',
#    'travel_time': 1416,
#    'trip_id': 901247,
#    'bus_name': 38,
#    'full_bus_name': '38_TO U.W. HOSPITAL: VIA WILSON'}],
#  '1878_28860': [{'destination': '1190_28912',
#    'travel_time': 52,
#    'trip_id': 885085,
#    'bus_name': 3,
#    'full_bus_name': '3_WEST TFR PT'},
#   {'destination': '1190_28982',
#    'travel_time': 122,
#    'trip_id': 895210,
#    'bus_name': 3,
#    'full_bus_name': '3_WEST TRANSFER'},
#   {'destination': '1190_30057',
#    'travel_time': 1197,
#    'trip_id': 885287,
#    'bus_name': 4,
#    'full_bus_name': '4_SOUTH TFR PT'},
#   {'destination': '1190_29997',
#    'travel_time': 1137,
#    'trip_id': 895429,
#    'bus_name': 4,
#    'full_bus_name': '4_SOUTH TRANSFER'},
#   {'destination': '1190_30290',
#    'travel_time': 1430,
#    'trip_id': 891082,
#    'bus_name': 38,
#    'full_bus_name': '38_TO UW HOSPITAL: VIA WILSON'},
#   {'destination': '1190_29390',
#    'travel_time': 530,
#    'trip_id': 891093,
#    'bus_name': 38,
#    'full_bus_name': '38_TO UW HOSPITAL: VIA WILSON'},
#   {'destination': '1190_29150',
#    'travel_time': 290,
#    'trip_id': 891096,
#    'bus_name': 38,
#    'full_bus_name': '38_TO UW HOSPITAL: VIA WILSON'},
#   {'destination': '1190_29990',
#    'travel_time': 1130,
#    'trip_id': 891097,
#    'bus_name': 38,
#    'full_bus_name': '38_TO UW HOSPITAL: VIA WILSON'},
#   {'destination': '1190_29990',
#    'travel_time': 1130,
#    'trip_id': 901232,
#    'bus_name': 38,
#    'full_bus_name': '38_TO U.W. HOSPITAL: VIA WILSON'},
#   {'destination': '1190_29150',
#    'travel_time': 290,
#    'trip_id': 901233,
#    'bus_name': 38,
#    'full_bus_name': '38_TO U.W. HOSPITAL: VIA WILSON'},
#   {'destination': '1190_29390',
#    'travel_time': 530,
#    'trip_id': 901236,
#    'bus_name': 38,
#    'full_bus_name': '38_TO U.W. HOSPITAL: VIA WILSON'},
#   {'destination': '1190_30290',
#    'travel_time': 1430,
#    'trip_id': 901247,
#    'bus_name': 38,
#    'full_bus_name': '38_TO U.W. HOSPITAL: VIA WILSON'}],
#  '1190_28912': [{'destination': '1536_28964',
#    'travel_time': 52,
#    'trip_id': 885085,
#    'bus_name': 3,
#    'full_bus_name': '3_WEST TFR PT'},
#   {'destination': '1536_29044',
#    'travel_time': 132,
#    'trip_id': 895210,
#    'bus_name': 3,
#    'full_bus_name': '3_WEST TRANSFER'},
#   {'destination': '1536_30114',
#    'travel_time': 1202,
#    'trip_id': 885287,
#    'bus_name': 4,
#    'full_bus_name': '4_SOUTH TFR PT'},
#   {'destination': '1536_30054',
#    'travel_time': 1142,
#    'trip_id': 895429,
#    'bus_name': 4,
#    'full_bus_name': '4_SOUTH TRANSFER'},
#   {'destination': '1536_30340',
#    'travel_time': 1428,
#    'trip_id': 891082,
#    'bus_name': 38,
#    'full_bus_name': '38_TO UW HOSPITAL: VIA WILSON'},
#   {'destination': '1536_29440',
#    'travel_time': 528,
#    'trip_id': 891093,
#    'bus_name': 38,
#    'full_bus_name': '38_TO UW HOSPITAL: VIA WILSON'},
#   {'destination': '1536_29200',
#    'travel_time': 288,
#    'trip_id': 891096,
#    'bus_name': 38,
#    'full_bus_name': '38_TO UW HOSPITAL: VIA WILSON'},
#   {'destination': '1536_30040',
#    'travel_time': 1128,
#    'trip_id': 891097,
#    'bus_name': 38,
#    'full_bus_name': '38_TO UW HOSPITAL: VIA WILSON'},
#   {'destination': '1536_30040',
#    'travel_time': 1128,
#    'trip_id': 901232,
#    'bus_name': 38,
#    'full_bus_name': '38_TO U.W. HOSPITAL: VIA WILSON'},
#   {'destination': '1536_29200',
#    'travel_time': 288,
#    'trip_id': 901233,
#    'bus_name': 38,
#    'full_bus_name': '38_TO U.W. HOSPITAL: VIA WILSON'},
#   {'destination': '1536_29440',
#    'travel_time': 528,
#    'trip_id': 901236,
#    'bus_name': 38,
#    'full_bus_name': '38_TO U.W. HOSPITAL: VIA WILSON'},
#   {'destination': '1536_30340',
#    'travel_time': 1428,
#    'trip_id': 901247,
#    'bus_name': 38,
#    'full_bus_name': '38_TO U.W. HOSPITAL: VIA WILSON'}],
#  '1536_28964': [{'destination': '1194_29015',
#    'travel_time': 51,
#    'trip_id': 885085,
#    'bus_name': 3,
#    'full_bus_name': '3_WEST TFR PT'},
#   {'destination': '1194_29105',
#    'travel_time': 141,
#    'trip_id': 895210,
#    'bus_name': 3,
#    'full_bus_name': '3_WEST TRANSFER'},
#   {'destination': '1194_30170',
#    'travel_time': 1206,
#    'trip_id': 885287,
#    'bus_name': 4,
#    'full_bus_name': '4_SOUTH TFR PT'},
#   {'destination': '1194_30110',
#    'travel_time': 1146,
#    'trip_id': 895429,
#    'bus_name': 4,
#    'full_bus_name': '4_SOUTH TRANSFER'},
#   {'destination': '1194_30389',
#    'travel_time': 1425,
#    'trip_id': 891082,
#    'bus_name': 38,
#    'full_bus_name': '38_TO UW HOSPITAL: VIA WILSON'},
#   {'destination': '1194_29489',
#    'travel_time': 525,
#    'trip_id': 891093,
#    'bus_name': 38,
#    'full_bus_name': '38_TO UW HOSPITAL: VIA WILSON'},
#   {'destination': '1194_29249',
#    'travel_time': 285,
#    'trip_id': 891096,
#    'bus_name': 38,
#    'full_bus_name': '38_TO UW HOSPITAL: VIA WILSON'},
#   {'destination': '1194_30089',
#    'travel_time': 1125,
#    'trip_id': 891097,
#    'bus_name': 38,
#    'full_bus_name': '38_TO UW HOSPITAL: VIA WILSON'},
#   {'destination': '1194_30089',
#    'travel_time': 1125,
#    'trip_id': 901232,
#    'bus_name': 38,
#    'full_bus_name': '38_TO U.W. HOSPITAL: VIA WILSON'},
#   {'destination': '1194_29249',
#    'travel_time': 285,
#    'trip_id': 901233,
#    'bus_name': 38,
#    'full_bus_name': '38_TO U.W. HOSPITAL: VIA WILSON'},
#   {'destination': '1194_29489',
#    'travel_time': 525,
#    'trip_id': 901236,
#    'bus_name': 38,
#    'full_bus_name': '38_TO U.W. HOSPITAL: VIA WILSON'},
#   {'destination': '1194_30389',
#    'travel_time': 1425,
#    'trip_id': 901247,
#    'bus_name': 38,
#    'full_bus_name': '38_TO U.W. HOSPITAL: VIA WILSON'}],
#  '1194_29015': [{'destination': '1720_29057',
#    'travel_time': 42,
#    'trip_id': 885085,
#    'bus_name': 3,
#    'full_bus_name': '3_WEST TFR PT'},
#   {'destination': '1720_29155',
#    'travel_time': 140,
#    'trip_id': 895210,
#    'bus_name': 3,
#    'full_bus_name': '3_WEST TRANSFER'},
#   {'destination': '1720_30216',
#    'travel_time': 1201,
#    'trip_id': 885287,
#    'bus_name': 4,
#    'full_bus_name': '4_SOUTH TFR PT'},
#   {'destination': '1720_30156',
#    'travel_time': 1141,
#    'trip_id': 895429,
#    'bus_name': 4,
#    'full_bus_name': '4_SOUTH TRANSFER'},
#   {'destination': '1720_30429',
#    'travel_time': 1414,
#    'trip_id': 891082,
#    'bus_name': 38,
#    'full_bus_name': '38_TO UW HOSPITAL: VIA WILSON'},
#   {'destination': '1720_29529',
#    'travel_time': 514,
#    'trip_id': 891093,
#    'bus_name': 38,
#    'full_bus_name': '38_TO UW HOSPITAL: VIA WILSON'},
#   {'destination': '1720_29289',
#    'travel_time': 274,
#    'trip_id': 891096,
#    'bus_name': 38,
#    'full_bus_name': '38_TO UW HOSPITAL: VIA WILSON'},
#   {'destination': '1720_30129',
#    'travel_time': 1114,
#    'trip_id': 891097,
#    'bus_name': 38,
#    'full_bus_name': '38_TO UW HOSPITAL: VIA WILSON'},
#   {'destination': '1720_30129',
#    'travel_time': 1114,
#    'trip_id': 901232,
#    'bus_name': 38,
#    'full_bus_name': '38_TO U.W. HOSPITAL: VIA WILSON'},
#   {'destination': '1720_29289',
#    'travel_time': 274,
#    'trip_id': 901233,
#    'bus_name': 38,
#    'full_bus_name': '38_TO U.W. HOSPITAL: VIA WILSON'},
#   {'destination': '1720_29529',
#    'travel_time': 514,
#    'trip_id': 901236,
#    'bus_name': 38,
#    'full_bus_name': '38_TO U.W. HOSPITAL: VIA WILSON'},
#   {'destination': '1720_30429',
#    'travel_time': 1414,
#    'trip_id': 901247,
#    'bus_name': 38,
#    'full_bus_name': '38_TO U.W. HOSPITAL: VIA WILSON'}],
#  '1720_29057': [{'destination': '1480_29089',
#    'travel_time': 32,
#    'trip_id': 885085,
#    'bus_name': 3,
#    'full_bus_name': '3_WEST TFR PT'},
#   {'destination': '1480_29193',
#    'travel_time': 136,
#    'trip_id': 895210,
#    'bus_name': 3,
#    'full_bus_name': '3_WEST TRANSFER'},
#   {'destination': '1480_30251',
#    'travel_time': 1194,
#    'trip_id': 885287,
#    'bus_name': 4,
#    'full_bus_name': '4_SOUTH TFR PT'},
#   {'destination': '1480_30191',
#    'travel_time': 1134,
#    'trip_id': 895429,
#    'bus_name': 4,
#    'full_bus_name': '4_SOUTH TRANSFER'},
#   {'destination': '1480_30460',
#    'travel_time': 1403,
#    'trip_id': 891082,
#    'bus_name': 38,
#    'full_bus_name': '38_TO UW HOSPITAL: VIA WILSON'},
#   {'destination': '1480_29560',
#    'travel_time': 503,
#    'trip_id': 891093,
#    'bus_name': 38,
#    'full_bus_name': '38_TO UW HOSPITAL: VIA WILSON'},
#   {'destination': '1480_29320',
#    'travel_time': 263,
#    'trip_id': 891096,
#    'bus_name': 38,
#    'full_bus_name': '38_TO UW HOSPITAL: VIA WILSON'},
#   {'destination': '1480_30160',
#    'travel_time': 1103,
#    'trip_id': 891097,
#    'bus_name': 38,
#    'full_bus_name': '38_TO UW HOSPITAL: VIA WILSON'},
#   {'destination': '1480_30160',
#    'travel_time': 1103,
#    'trip_id': 901232,
#    'bus_name': 38,
#    'full_bus_name': '38_TO U.W. HOSPITAL: VIA WILSON'},
#   {'destination': '1480_29320',
#    'travel_time': 263,
#    'trip_id': 901233,
#    'bus_name': 38,
#    'full_bus_name': '38_TO U.W. HOSPITAL: VIA WILSON'},
#   {'destination': '1480_29560',
#    'travel_time': 503,
#    'trip_id': 901236,
#    'bus_name': 38,
#    'full_bus_name': '38_TO U.W. HOSPITAL: VIA WILSON'},
#   {'destination': '1480_30460',
#    'travel_time': 1403,
#    'trip_id': 901247,
#    'bus_name': 38,
#    'full_bus_name': '38_TO U.W. HOSPITAL: VIA WILSON'}],
#  ...}

# %%
def get_stop(node):
    return int(node.split("_")[0])
    
def get_seconds(node):
    return int(node.split("_")[1])
    
# depth-first search through bus system
#
# graph: dict, key=node name, val=edge list
# node: node name
# max_time: last time (in seconds) beyond which we don't search (None if no limit)
# visited: set of nodes visited already (to avoid repeats)
def dfs(graph, node, max_time=None, visited=None, parent_node):

    if visited == None:
        visited = set()

    node_time = get_seconds(node)
    if max_time != None and node_time > max_time:
        return visited

    if node in visited:
        return visited
    
    trip_id = edge['trip_id'] 
    visited.add(node)
    for edge in graph[node]:
        
        if 'DROP OFF' in edge['bus_full_name']:
            if edge['trip_id'] == trip_id:
                pass
            else: 
                continue
           
        dfs(graph, edge["destination"], max_time, visited, edge)

    return visited

def stops_reachable_percent(start, hours=None):
    limit = None
    if hours != None:
        limit = get_seconds(start) + hours * 360 # hours to seconds
    reachable = dfs(g, start, limit)
    reachable_stops = {get_stop(node) for node in reachable}
    all_stops = {get_stop(node) for node in g.keys()}
    return len(reachable_stops) / len(all_stops)    

# where can we get if we start at this place/time, and have no time limit?
print(stops_reachable_percent('1561_25223'))

# one hour limit?
print(stops_reachable_percent('1561_25223', 1))

# two hour limit?
print(stops_reachable_percent('1561_25223', 2))
# Out:
# 0.9806736609607951
# 0.00717835450027609
# 0.02263942573163998

# %%
hour_coverage = {}
past_percent = -1
for i,node in enumerate(g):
    hour_coverage[node] = stops_reachable_percent(node, 1)
    if i*100//len(g) != past_percent:
        past_percent = i*100//len(g)
        print("%d%% done" % past_percent)
best = max(hour_coverage.values())
print([n for n in g if hour_coverage[n] == best])
# Out:
# 0% done
# 1% done
# 2% done
# 3% done
# 4% done
# 5% done
# 6% done
# 7% done
# 8% done
# 9% done
# 10% done
# 11% done
# 12% done
# 13% done
# 14% done
# 15% done
# 16% done
# 17% done
# 18% done
# 19% done
# 20% done
# 21% done
# 22% done
# 23% done
# 24% done
# 25% done
# 26% done
# 27% done
# 28% done
# 29% done
# 30% done
# 31% done
# 32% done
# 33% done
# 34% done
# 35% done
# 36% done
# 37% done
# 38% done
# 39% done
# 40% done
# 41% done
# 42% done
# 43% done
# 44% done
# 45% done
# 46% done
# 47% done
# 48% done
# 49% done
# 50% done
# 51% done
# 52% done
# 53% done
# 54% done
# 55% done
# 56% done
# 57% done
# 58% done
# 59% done
# 60% done
# 61% done
# 62% done
# 63% done
# 64% done
# 65% done
# 66% done
# 67% done
# 68% done
# 69% done
# 70% done
# 71% done
# 72% done
# 73% done
# 74% done
# 75% done
# 76% done
# 77% done
# 78% done
# 79% done
# 80% done
# 81% done
# 82% done
# 83% done
# 84% done
# 85% done
# 86% done
# 87% done
# 88% done
# 89% done
# 90% done
# 91% done
# 92% done
# 93% done
# 94% done
# 95% done
# 96% done
# 97% done
# 98% done
# 99% done
# ['6100_26100']
